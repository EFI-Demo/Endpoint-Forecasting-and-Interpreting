# %%
from graphviz import Digraph

# %%
'''
20181112-TRACE
Information gather and exfiltration (Host A)

'''

sub_tech_dot = 'Information gather and exfiltration (Host A)_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"', 'size="9"', 'fixedsize="false"', 'splines="true"', 'nodesep=0.3', 'ranksep=0', 'fontsize=10', 'overlap="scalexy"',
        'engine= "neato"'])
edge_counter = 1

mal = 'hostA_P'
cat_P = 'cat_P'
g.node(mal, shape='box', node_type="Process")
g.node(cat_P, shape='box', node_type="Process")
g.edge(mal, cat_P, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

cat_F = 'cat_F2'
g.node(cat_F, shape='ellipse', node_type="File")
g.edge(cat_P, cat_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

file1 = '/etc/shadow_F0'
g.node(file1, shape='ellipse', node_type="File")
g.edge(cat_P, file1, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

config_P = 'config_P'
g.node(config_P, shape='box', node_type="Process")
g.edge(mal, config_P, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

config_F = 'config_F2'
g.node(config_F, shape='ellipse', node_type="File")
g.edge(config_P, config_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

tcpdump_P = 'tcpdump_P'
g.node(tcpdump_P, shape='box', node_type="Process")
g.edge(mal, tcpdump_P, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

tcpdump_F = 'tcpdump_F2'
g.node(tcpdump_F, shape='ellipse', node_type="File")
g.edge(tcpdump_P, tcpdump_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

ps_P = 'ps_P'
g.node(ps_P, shape='box', node_type="Process")
g.edge(mal, ps_P, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

ps_F = 'ps_F2'
g.node(ps_F, shape='ellipse', node_type="File")
g.edge(ps_P, ps_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

groups_P = 'groups_P'
g.node(groups_P, shape='box', node_type="Process")
g.edge(mal, groups_P, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

groups_F = 'groups_F2'
g.node(groups_F, shape='ellipse', node_type="File")
g.edge(groups_P, groups_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

dirname_P = 'dirname_P'
g.node(dirname_P, shape='box', node_type="Process")
g.edge(mal, dirname_P, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

dirname_F = 'dirname_F2'
g.node(dirname_F, shape='ellipse', node_type="File")
g.edge(dirname_P, dirname_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

file2 = '/etc/passwd_F0'
g.node(file2, shape='ellipse', node_type="File")
g.edge(mal, file2, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

file3 = '/dev/pts/1_F3'
g.node(file3, shape='ellipse', node_type="File")
g.edge(mal, file3, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

IP1 = '128.55.12.118_S'
IP2 = '128.55.12.79_S'
g.node(IP1, shape='diamond', node_type="Socket")
g.node(IP2, shape='diamond', node_type="Socket")
g.edge(mal, IP1, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(IP1, mal, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1
g.edge(mal, IP2, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(IP2, mal, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

g.view()
# Out:
# 'Information gather and exfiltration (Host A)_man.dot.pdf'

# %%
'''
20181112-TRACE
In-memory attack with firefox (Host B)
'''
#?
# 完全版
sub_tech_dot = 'In-memory attack with firefox (Host B)_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"', 'size="9"', 'fixedsize="false"', 'splines="true"', 'nodesep=0.3', 'ranksep=0', 'fontsize=10', 'overlap="scalexy"',
        'engine= "neato"'])
edge_counter = 1

firefox = 'firefox_P'
g.node(firefox, shape='box', node_type="Process")

file0 = '/dev/glx_alsa_675_F3'
g.node(file0, shape='ellipse', node_type="File")
g.edge(firefox, file0, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

file1 = '/tmp/libnet.so_F1'
g.node(file1, shape='ellipse', node_type="File")
g.edge(firefox, file1, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

s0 = '86.129.31.201_S'
g.node(s0, shape='diamond', node_type="Socket")
g.edge(firefox, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(s0, firefox, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

sshd = 'sshd_P'
g.node(sshd, shape='box', node_type="Process")
g.edge(sshd, file1, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1
g.edge(sshd, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(s0, sshd, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

file2 = '/home/admin/files/docs/audiobackup_F3'
g.node(file2, shape='ellipse', node_type="File")
g.edge(sshd, file2, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

P1 = '/home/admin/files/docs/audiobackup_P'
g.node(P1, shape='box', node_type="Process")
g.edge(sshd, P1, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(P1, file2, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

s1 = '25.7.74.53_S'
g.node(s1, shape='diamond', node_type="Socket")
g.edge(P1, s1, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1

file3= 'Host and passwd files_F0'
g.node(file3, shape='ellipse', node_type="File")
g.edge(sshd, file3, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(sshd, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1

s2 = '98.66.41.61_S'
g.node(s2, shape='diamond', node_type="Socket")
g.edge(firefox, s2, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1

g.view()
# Out:
# 'In-memory attack with firefox (Host B)_man.dot.pdf'

# %%
'''
20181112-TRACE
In-memory attack with firefox (Host B)
'''
#?
# 简约版
sub_tech_dot = 'In-memory attack with firefox (Host B)_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"', 'size="9"', 'fixedsize="false"', 'splines="true"', 'nodesep=0.3', 'ranksep=0', 'fontsize=10', 'overlap="scalexy"',
        'engine= "neato"'])
edge_counter = 1

firefox = 'firefox_P'
g.node(firefox, shape='box', node_type="Process")

file0 = '/dev/glx_alsa_675_F3'
g.node(file0, shape='ellipse', node_type="File")
g.edge(firefox, file0, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

file1 = '/tmp/libnet.so_F1'
g.node(file1, shape='ellipse', node_type="File")
g.edge(firefox, file1, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

s0 = '86.129.31.201_S'
g.node(s0, shape='diamond', node_type="Socket")
g.edge(firefox, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(s0, firefox, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

# sshd = 'sshd_P'
# g.node(sshd, shape='box', node_type="Process")
# g.edge(sshd, file1, label=str(edge_counter) + ': ' + 'load')
# edge_counter += 1
# g.edge(sshd, s0, label=str(edge_counter) + ': ' + 'send')
# edge_counter += 1
# g.edge(s0, sshd, label=str(edge_counter) + ': ' + 'receive')
# edge_counter += 1

file2 = '/home/admin/files/docs/audiobackup_F3'
g.node(file2, shape='ellipse', node_type="File")
g.edge(firefox, file2, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

P1 = '/home/admin/files/docs/audiobackup_P'
g.node(P1, shape='box', node_type="Process")
g.edge(firefox, P1, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(P1, file2, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

s1 = '25.7.74.53_S'
g.node(s1, shape='diamond', node_type="Socket")
g.edge(firefox, s1, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1

file3= 'Host and passwd files_F0'
g.node(file3, shape='ellipse', node_type="File")
g.edge(firefox, file3, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(firefox, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1

s2 = '98.66.41.61_S'
g.node(s2, shape='diamond', node_type="Socket")
g.edge(firefox, s2, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1

g.view()
# Out:
# 'In-memory attack with firefox (Host B)_man.dot.pdf'

# %%
'''
20181112-TRACE
Malicious file download and execute (Host A)
1. ccleaner attack
'''

sub_tech_dot = 'ccleaner attack_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"', 'size="9"', 'fixedsize="false"', 'splines="true"', 'nodesep=0.3', 'ranksep=0', 'fontsize=10', 'overlap="scalexy"',
        'engine= "neato"'])
edge_counter = 1

p0 = 'scp_P'
g.node(p0, shape='box', node_type="Process")

s0 = 'unknown location_S'
g.node(s0, shape='diamond', node_type="Socket")
g.edge(s0, p0, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

f0 = '/home/admin/ccleaner_F3'
g.node(f0, shape='ellipse', node_type="File")
g.edge(p0, f0, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

p1 = 'firefox_P'
g.node(p1, shape='box', node_type="Process")

s0 = '64.95.25.213_S'
g.node(s0, shape='diamond', node_type="Socket")
g.edge(p1, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(s0, p1, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

f1 = 'SrcSinkObject_F3'
g.node(f1, shape='ellipse', node_type="File")
g.edge(p1, f1, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(p0, f1, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

p2 = '/home/admin/ccleaner_P'
g.node(p2, shape='box', node_type="Process")
g.edge(p0, p2, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(p2, f0, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

f2 = 'information_F3'
g.node(f2, shape='ellipse', node_type="File")
g.edge(p2, f2, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

p3 = 'dbus daemon_P'
g.node(p3, shape='box', node_type="Process")
g.edge(p2, p3, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1

f3 = '/proc/filesystem_F3'
g.node(f3, shape='ellipse', node_type="File")
g.edge(p3, f3, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

f4 = '/proc/mount_F0'
g.node(f4, shape='ellipse', node_type="File")
g.edge(p3, f4, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

f5 = '/etc/passwd_F0'
g.node(f5, shape='ellipse', node_type="File")
g.edge(p3, f5, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1



g.view()
# Out:
# 'ccleaner attack_man.dot.pdf'

# %%
'''
20181112-TRACE
Malicious file download and execute (Host A)
2. hc attack
'''

sub_tech_dot = 'hc attack_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"', 'size="9"', 'fixedsize="false"', 'splines="true"', 'nodesep=0.3', 'ranksep=0', 'fontsize=10', 'overlap="scalexy"',
        'engine= "neato"'])
edge_counter = 1

p0 = 'scp_P'
g.node(p0, shape='box', node_type="Process")

s0 = '108.25.125.188_S'
g.node(s0, shape='diamond', node_type="Socket")
g.edge(s0, p0, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

f0 = '/usr/local/bin/hc_F3'
g.node(f0, shape='ellipse', node_type="File")
g.edge(p0, f0, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

p1 = 'hc_P'
g.node(p1, shape='box', node_type="Process")
g.edge(p0, p1, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(p1, f0, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

f1 = 'bluetooth service.dll_F1'
g.node(f1, shape='ellipse', node_type="File")
g.edge(p1, f1, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1

f2 = 'volume monitor.dll_F1'
g.node(f2, shape='ellipse', node_type="File")
g.edge(p1, f2, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1

f3 = 'power service.lib_F1'
g.node(f3, shape='ellipse', node_type="File")
g.edge(p1, f3, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1

f4 = 'firefox_F3'
g.node(f4, shape='ellipse', node_type="File")
g.edge(p1, f4, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1

f5 = '/proc/net_F3'
g.node(f5, shape='ellipse', node_type="File")
g.edge(p1, f5, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

f6 = '/etc/passwd_F0'
g.node(f6, shape='ellipse', node_type="File")
g.edge(p1, f6, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1

s0 = '128.55.12.185_S'
g.node(s0, shape='diamond', node_type="Socket")
g.edge(p1, s0, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
g.edge(s0, p1, label=str(edge_counter) + ': ' + 'receive')
edge_counter += 1

f7 = '/tmp/ext96481_F3'
g.node(f7, shape='ellipse', node_type="File")
g.edge(p1, f7, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1

p2 = '/tmp/ext96481_P'
g.node(p2, shape='box', node_type="Process")
g.edge(p1, p2, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(p2, f7, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1

g.edge(p2, f6, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1



g.view()
# Out:
# 'hc attack_man.dot.pdf'

# %%
'''
Deputy Dog 
'''

sub_tech_dot = 'DeputyDog_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_B = '*_P'
mal_A = '*.\%exe\%_P'
file_A = '*.\%exe\%_F2'
file_C = '28542CC0.dll_F1'
registry_D = 'HKLM\\\\Software\\\\Microsoft\\\\Windows\\\\CurrentVersion\\\\Run\\\\_R1'
socket1_E = '\%External IP address\%_S'

g.node(mal_B, shape='box', node_type="Process")
g.node(mal_A, shape='box', node_type="Process")
g.node(file_A, shape='ellipse', node_type="File")
g.node(file_C, shape='ellipse', node_type="File")
g.node(registry_D, shape='parallelogram', node_type="Registry")
g.node(socket1_E, shape='diamond', node_type="Socket")

g.edge(mal_B, mal_A, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_A, file_A, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_A, file_C, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, registry_D, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, socket1_E, label=str(edge_counter) + ': ' + 'send')
edge_counter += 1
# g.edge(socket1_E, mal_A, label=str(edge_counter) + ': ' + 'receive')
# edge_counter += 1

g.view()
# Out:
# 'DeputyDog_man.dot.pdf'

# %%
sub_tech_dot = 'Carbanak_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_A = '\%Mail Application\%_P'
mal_C = '*_P'
mal_E = 'svchost_P'
mal_F = '*Sys$_P'
mal_B = '*.\%exe\%_P'
mal_D = '\%system32\%\\\\svchost_P'
file_B = '*.\%exe\%_F2'
file_D = '\%system32\%\\\\svchost_F0'
file_G = '\%COMMON_APPDATA\%\\\\Mozilla\\\\*.\%exe\%_F2'
file_I = '\%AppData\%\\\\Mozilla\\\\Firefox\\\\*\\\\prefs.js_F2'
registry_H = '[HKCU]\\\\Software\\\\Microsoft\\\\Windows\\\\CurrentVersion\\\\Internet Settings_R2'
socket1_J = '\%External IP address\%_S'

g.node(mal_A, shape='box', node_type="Process")
g.node(mal_C, shape='box', node_type="Process")
g.node(mal_E, shape='box', node_type="Process")
g.node(mal_F, shape='box', node_type="Process")
g.node(mal_B, shape='box', node_type="Process")
g.node(mal_D, shape='box', node_type="Process")

g.node(file_B, shape='ellipse', node_type="File")
g.node(file_D, shape='ellipse', node_type="File")
g.node(file_G, shape='ellipse', node_type="File")
g.node(file_I, shape='ellipse', node_type="File")
g.node(registry_H, shape='parallelogram', node_type="Registry")
g.node(socket1_J, shape='diamond', node_type="Socket")

g.edge(mal_A, file_B, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_C, mal_B, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_B, file_B, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_C, file_D, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_E, mal_D, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_D, file_D, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_E, file_B, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_E, mal_F, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_E, file_G, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_E, registry_H, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_E, file_I, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_E, socket1_J, label=str(edge_counter) + ': ' + 'send')
g.view()
# Out:
# 'Carbanak_man.dot.pdf'

# %%
sub_tech_dot = 'DustySky_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_B = '*1_P'
mal_C = '\%Microsoft Word\%_P'
mal_H = '*2_P'
mal_A = '*.\%exe\%_P'
mal_G = '\%TEMP\%\\\\*.\%exe\%_P'
file_A = '*.\%exe\%_F2'
file_D = '*\\\\vboxmrxnp.dll_F1'
file_E = '*\\\\vmbusres.dll_F1'
file_F = '*\\\\vmGuestlib.dll_F1'
# file_G = '\%TEMP\%\\\\*.\%exe\%_F2'
file_I = '\%TEMP%\\\\temps_F3'

g.node(mal_B, shape='box', node_type="Process")
g.node(mal_C, shape='box', node_type="Process")
g.node(mal_H, shape='box', node_type="Process")
g.node(mal_A, shape='box', node_type="Process")
g.node(mal_G, shape='box', node_type="Process")
g.node(file_A, shape='ellipse', node_type="File")
g.node(file_D, shape='ellipse', node_type="File")
g.node(file_E, shape='ellipse', node_type="File")
g.node(file_F, shape='ellipse', node_type="File")
# g.node(file_G, shape='ellipse', node_type="File")
g.node(file_I, shape='ellipse', node_type="File")

g.edge(mal_B, mal_A, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_A, file_A, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_B, mal_C, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_C, file_A, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_B, file_D, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_B, file_E, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_B, file_F, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
# g.edge(mal_B, file_G, label=str(edge_counter) + ': ' + 'write')
# edge_counter += 1
g.edge(mal_B, mal_H, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_H, mal_G, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
# g.edge(mal_G, file_G, label=str(edge_counter) + ': ' + 'exec')
# edge_counter += 1
g.edge(mal_H, file_I, label=str(edge_counter) + ': ' + 'write')
g.view()
# Out:
# 'DustySky_man.dot.pdf'

# %%
sub_tech_dot = 'Uroburos_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_A = '*_P'
mal_D = 'rundll32_P'
file_B = '\%APPDATA\%\\\\Microsoft\\\\credprov.tlb_F1'
file_C = '\%APPDATA\%\\\\Microsoft\\\\shdocvw.tlb_F1'
file_F = '*\\\\winview.ocx_F3'
file_G = '*\\\\mskfp32.ocx_F3'
file_H = '*\\\\msvcrtd.tlb_F1'
file_I = '\%APPDATA\%\\\\Microsoft\\\\oleaut32.dll_F1'
file_J = '\%APPDATA%\\\\Microsoft\\\\oleaut32.tlb_F1'
file_K = '\%APPDATA%\\\\Microsoft\\\\libadcodec.dll_F1'
file_L = '\%APPDATA%\\\\Microsoft\\\\libadcodec.tlb_F1'
registry_E = '[HKCU]\\\\Software\\\\Classes\\\\CLSID\\\\42aedc87-2188-41fd-b9a3-0c966feabec1\\\\_R2'

g.node(mal_A, shape='box', node_type="Process")
g.node(mal_D, shape='box', node_type="Process")
g.node(file_B, shape='ellipse', node_type="File")
g.node(file_C, shape='ellipse', node_type="File")
g.node(file_F, shape='ellipse', node_type="File")
g.node(file_G, shape='ellipse', node_type="File")
g.node(file_H, shape='ellipse', node_type="File")
g.node(file_I, shape='ellipse', node_type="File")
g.node(file_J, shape='ellipse', node_type="File")
g.node(file_K, shape='ellipse', node_type="File")
g.node(file_L, shape='ellipse', node_type="File")
g.node(registry_E, shape='parallelogram', node_type="Registry")

g.edge(mal_A, file_B, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_C, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, mal_D, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_D, file_B, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1
g.edge(mal_D, file_C, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1
g.edge(mal_A, registry_E, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_F, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_G, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_H, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_C, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_A, file_B, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_A, file_I, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_A, file_J, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_A, file_K, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_A, file_L, label=str(edge_counter) + ': ' + 'unlink')
g.view()
# Out:
# 'Uroburos_man.dot.pdf'

# %%
sub_tech_dot = 'OceanLotus_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_A = '*.\%exe\%_P'
mal_B = '*_P'
mal_E = '\%Microsoft Word\%_P'
mal_I = 'rastlsc_P'
mal_C = '\%temp\%\\\\_P'
mal_F = '*\\\\rastlsc.\%exe\%_P'
file_A = '*.\%exe\%_F2'
file_C = '\%temp\%\\\\*_F3'
file_D = '\%temp\%\\\\[0-9].tmp.\%exe\%_F2'
file_F = '*\\\\rastlsc.\%exe\%_F2'
file_G = '*\\\\rastls.dll_F1'
file_H = '*\\\\(Sylog.bin|OUTLFLTR.DAT)_F3'
file_K = '*\\\\HTTPProv.dll_F1'
registry_J = '\\\\SOFTWARE\\\\Classes\\\\AppX*_R1'
registry_L = 'SOFTWARE\\\\Classes\\\\CLSID\\\\{E3517E26-8E93-458D-A6DF-8030BC80528B}_R1'
socket1_M = '\%External IP address\%_S'

g.node(mal_A, shape='box', node_type="Process")
g.node(mal_B, shape='box', node_type="Process")
g.node(mal_E, shape='box', node_type="Process")
g.node(mal_I, shape='box', node_type="Process")
g.node(mal_C, shape='box', node_type="Process")
g.node(mal_F, shape='box', node_type="Process")

g.node(file_A, shape='ellipse', node_type="File")
g.node(file_C, shape='ellipse', node_type="File")
g.node(file_D, shape='ellipse', node_type="File")
g.node(file_F, shape='ellipse', node_type="File")
g.node(file_G, shape='ellipse', node_type="File")
g.node(file_H, shape='ellipse', node_type="File")
g.node(file_K, shape='ellipse', node_type="File")
g.node(registry_J, shape='parallelogram', node_type="Registry")
g.node(registry_L, shape='parallelogram', node_type="Registry")
g.node(socket1_M, shape='diamond', node_type="Socket")

g.edge(mal_B, mal_A, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_A, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_B, file_C, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_B, file_D, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_B, mal_E, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_E, file_D, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_E, mal_C, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_C, file_C, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_B, file_F, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_B, file_G, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_B, file_H, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_B, mal_I, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_I, mal_F, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_F, file_F, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_I, file_H, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1
g.edge(mal_I, file_G, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_I, registry_J, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_I, file_K, label=str(edge_counter) + ': ' + 'load')
edge_counter += 1
g.edge(mal_I, registry_L, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_I, socket1_M, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(socket1_M, mal_I, label=str(edge_counter) + ': ' + 'read')
g.view()
# Out:
# 'OceanLotus_man.dot.pdf'

# %%
sub_tech_dot = 'njRAT_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_A = '*1_P'
mal_F = '*2_P'
mal_I = 'netsh_P'
mal_E = '\%APPDATA\%\\\\_P'
file_B = '*.exe.config_F0'
file_C = '*.tmp_F3'
file_D = 'C \\\\WINDOWS\\\\Prefetch\\\\*.EXE-*.pf_F3'
file_E = '\%APPDATA\%\\\\_F3'
file_G = 'C \\\\WINDOWS\\\\Prefetch\\\\*.EXE-*.pf_F3'
file_H = '\%USER_PROFILE\%\\\\Start Menu\\\\Programs\\\\Startup\\\\*_F3'
file_J = 'C \\\\WINDOWS\\\\Prefetch\\\\NETSH.EXE-*.pf_F3'

registry_K = '[HKCU]\\\\Software\\\\Microsoft\\\\Windows\\\\CurrentVersion\\\\Run\\\\_R2'
registry_L = '[HKLM]\\\\Software\\\\Microsoft\\\\Windows\\\\CurrentVersion\\\\Run\\\\_R1'
registry_M = '[HKLM]\\\\SYSTEM\\\\CurrentControlSet\\\\Services\\\\SharedAccess\\\\-Parameters\\\\FirewallPolicy\\\\StandardProfile\\\\Authorized-Applications\\\\List\\\\APPDATA\\\\_R1'
socket1_N = '\%External IP address\%_S'

g.node(mal_A, shape='box', node_type="Process")
g.node(mal_F, shape='box', node_type="Process")
g.node(mal_I, shape='box', node_type="Process")
g.node(mal_E, shape='box', node_type="Process")

g.node(file_B, shape='ellipse', node_type="File")
g.node(file_C, shape='ellipse', node_type="File")
g.node(file_D, shape='ellipse', node_type="File")
g.node(file_E, shape='ellipse', node_type="File")
g.node(file_G, shape='ellipse', node_type="File")
g.node(file_H, shape='ellipse', node_type="File")
g.node(file_J, shape='ellipse', node_type="File")
g.node(registry_K, shape='parallelogram', node_type="Registry")
g.node(registry_L, shape='parallelogram', node_type="Registry")
g.node(registry_M, shape='parallelogram', node_type="Registry")
g.node(socket1_N, shape='diamond', node_type="Socket")

g.edge(mal_A, file_B, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_A, file_C, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_D, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_A, file_E, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, mal_F, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_F, mal_E, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_E, file_E, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_F, file_G, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, file_H, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, mal_I, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_I, file_J, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, registry_K, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, registry_L, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, registry_M, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_A, socket1_N, label=str(edge_counter) + ': ' + 'send')

g.view()
# Out:
# 'njRAT_man.dot.pdf'

# %%
sub_tech_dot = 'HawkEye_man.dot'
g = Digraph(sub_tech_dot, filename=sub_tech_dot)
g.body.extend(
    ['rankdir="LR"',
     'size="9"',
     'fixedsize="false"',
     'splines="true"',
     'nodesep=0.3',
     'ranksep=0',
     'fontsize=10',
     'overlap="scalexy"',
     'engine= "neato"'])
edge_counter = 1

mal_B = '\%Unachiever\%_P'
mal_D = '*_P'
mal_E = 'RegAsm_P'
mal_F = 'vbc1_P'
mal_G = 'vbc2_P'
mal_C = '*.\%exe\%_P'
file_A = '*.\%Compressed\%_F3'
file_C = '*.\%exe\%_F3'
file_J = '\%temp\%\\\\*.tmp_F3'
file_K = '\%temp\%\\\\*.tmp_F3'

registry_H1 = '*Opera*_R'
registry_H2 = '*Chrome*_R'
registry_H3 = '*Chromium*_R'
registry_H4 = '*Chrome SxS*_R'
registry_H5 = '*Thunderbird*_R'
registry_H6 = '*SeaMonkey*_R'
registry_H7 = '*SunBird*_R'
registry_H8 = '*IE*_R'
registry_H9 = '*Safari*_R'
registry_H10 = '*Firefox*_R'
registry_H11 = '*Yandex*_R'
registry_H12 = '*Vivaldi*_R'
registry_I1 = '*Yahoo*_R'
registry_I2 = '*GroupMail*_R'
registry_I3 = '*Thunderbird*_R'
registry_I4 = '*MSNMessenger*_R'
registry_I5 = '*Windows Mail*_R'
registry_I6 = '*IncrediMail*_R'
registry_I7 = '*Outlook*_R'
registry_I8 = '*Eudora*_R'
socket1_M = '\%External IP address\%_S'
socket2_L = 'http[s] \\\\\\\\whatismyipaddress.com\\\\*_S'

g.node(mal_B, shape='box', node_type="Process")
g.node(mal_D, shape='box', node_type="Process")
g.node(mal_E, shape='box', node_type="Process")
g.node(mal_F, shape='box', node_type="Process")
g.node(mal_G, shape='box', node_type="Process")
g.node(mal_C, shape='box', node_type="Process")
g.node(file_A, shape='ellipse', node_type="File")
g.node(file_C, shape='ellipse', node_type="File")
g.node(file_J, shape='ellipse', node_type="File")
g.node(file_K, shape='ellipse', node_type="File")

g.node(registry_H1, shape='parallelogram', node_type="Registry")
g.node(registry_H2, shape='parallelogram', node_type="Registry")
g.node(registry_H3, shape='parallelogram', node_type="Registry")
g.node(registry_H4, shape='parallelogram', node_type="Registry")
g.node(registry_H5, shape='parallelogram', node_type="Registry")
g.node(registry_H6, shape='parallelogram', node_type="Registry")
g.node(registry_H7, shape='parallelogram', node_type="Registry")
g.node(registry_H8, shape='parallelogram', node_type="Registry")
g.node(registry_H9, shape='parallelogram', node_type="Registry")
g.node(registry_H10, shape='parallelogram', node_type="Registry")
g.node(registry_H11, shape='parallelogram', node_type="Registry")
g.node(registry_H12, shape='parallelogram', node_type="Registry")
g.node(registry_I1, shape='parallelogram', node_type="Registry")
g.node(registry_I2, shape='parallelogram', node_type="Registry")
g.node(registry_I3, shape='parallelogram', node_type="Registry")
g.node(registry_I4, shape='parallelogram', node_type="Registry")
g.node(registry_I5, shape='parallelogram', node_type="Registry")
g.node(registry_I6, shape='parallelogram', node_type="Registry")
g.node(registry_I7, shape='parallelogram', node_type="Registry")
g.node(registry_I8, shape='parallelogram', node_type="Registry")
g.node(socket1_M, shape='diamond', node_type="Socket")
g.node(socket2_L, shape='diamond', node_type="Socket")

g.edge(mal_B, file_A, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_B, file_C, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_D, mal_C, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_C, file_C, label=str(edge_counter) + ': ' + 'exec')
edge_counter += 1
g.edge(mal_D, mal_E, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_F, mal_E, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_E, mal_G, label=str(edge_counter) + ': ' + 'fork')
edge_counter += 1
g.edge(mal_F, registry_H1, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H2, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H3, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H4, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H5, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H6, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H7, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H8, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H9, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H10, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H11, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_H12, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I1, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I2, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I3, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I4, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I5, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I6, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I7, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, registry_I8, label=str(edge_counter) + ': ' + 'open')
edge_counter += 1
g.edge(mal_F, file_J, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_G, file_K, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_E, file_J, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_E, file_K, label=str(edge_counter) + ': ' + 'read')
edge_counter += 1
g.edge(mal_E, file_J, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_E, file_K, label=str(edge_counter) + ': ' + 'unlink')
edge_counter += 1
g.edge(mal_E, socket1_M, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_E, socket2_L, label=str(edge_counter) + ': ' + 'write')
edge_counter += 1
g.edge(mal_E, socket2_L, label=str(edge_counter) + ': ' + 'read')

g.view()
# Out:
# 'HawkEye_man.dot.pdf'
